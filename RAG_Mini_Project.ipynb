# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhumithaselva/AppliedML/blob/main/RAG_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install Libraries**

# %%
# Install compatible versions together
# !pip install langchain-google-genai langchain langchain-community -q
# !pip install chromadb -q
# !pip install sentence-transformers -q
# !pip install pypdf -q
# !pip install streamlit -q
# !pip install pyngrok -q

print("All libraries installed!")
# Out:
# All libraries installed!
